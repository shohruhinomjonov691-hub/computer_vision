# %% [markdown]
# <a href="https://colab.research.google.com/github/shohruhinomjonov691-hub/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
# !rm -rf /content/plov_images

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/plov_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/plov_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 25 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://static.wixstatic.com/media/18cf5b_f7f5507447a44102bdf03e812ac79cea~mv2.png/v1/fill/w_980,h_757,al_c,q_90,usm_0.66_1.00_0.01,enc_avif,quality_auto/18cf5b_f7f5507447a44102bdf03e812ac79cea~mv2.png
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://thedailynotes.com/wp-content/uploads/2024/08/Types-Of-Employee-Resource-Groups.jpg
# [!] Issue getting: https://thedailynotes.com/wp-content/uploads/2024/08/Types-Of-Employee-Resource-Groups.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #2 from https://www.collidu.com/media/catalog/product/img1/2/a/2ac3b84f7da1814d3990d6caad3d5f0290bc785084d1cb2abc65071c0eb1a5fd/employee-resource-group-slide7.png
# [%] File Downloaded!
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/plov_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/plov'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
downloader.download("kebab food",
                     limit=100,
                     output_dir='/content/kebab_images',
                     adult_filter_off=True,
                     force_replace=False,
                     timeout=60)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.etsystatic.com/60205210/r/il/230ec0/7029875102/il_794xN.7029875102_2rf0.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://img-new.cgtrader.com/items/5260196/6bd13b9016/large/gangle-cosplay-mask-3d-model-6bd13b9016.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.etsystatic.com/54803723/r/il/ffea97/6505831788/il_1588xN.6505831788_p9st.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/31/0d/fc/310dfc9913ddc4f968eac57b185b2abf.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://i.ytimg.com/vi/W2f6IlX8EPE/maxresdefault.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/QlNdh7C42i4/maxresdefault.jpg
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
