# %% [markdown]
# <a href="https://colab.research.google.com/github/shohruhinomjonov691-hub/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/cat_image.jpg")

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=703x463>

# %%
print("SHAPE:", image.shape)
# 463 => height
# 703 => width
# 3   => color channels (BGR) Blue, Green, Red
print("HEIGHT:", image.shape[0])
print("WIDTH:", image.shape[1])
print("CHANNELS:", image.shape[2])
# Out:
# SHAPE: (463, 703, 3)
# HEIGHT: 463
# WIDTH: 703
# CHANNELS: 3

# %%
(b, g, r) = image[100, 50]
print("Blue:", b, "Green", g, "Red:", r)
# Out:
# Blue: 63 Green 133 Red: 70

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #BGR2LAB, BGR2RGB,BGR2HSV
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=703x463>

# %%
resized = cv2.resize(gray, (300, 300))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
cropped = gray[100:300, 150:350]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=L size=463x703>

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)
# Out:
# <PIL.Image.Image image mode=L size=703x463>

# %%
cv2.imwrite("cropped_cat.jpg", cropped)
# Out:
# True

# %%
cropped_cat = cv2.imread("/content/cropped_cat.jpg")
cv2_imshow(cropped_cat)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %% [markdown]
# # **Opencv video streaming codes**

# %%
import cv2
print("Hello World!")


cap = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    success, frame = cap.read()

    if not success:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.8, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow("Real-Time Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# =====================================

# import cv2

# url = 'https://www.youtube.com/watch?v=QH2-TGUlwu4'

# cap = cv2.VideoCapture(0) # url

# while True:
#     success, frame = cap.read()  # True, False | Boolean
#     if not success:
#         break
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     blurred = cv2.GaussianBlur(frame, (15, 15), 0)
#     edges1 = cv2.Canny(frame, 100, 200)  # Edge detection
#     edges2 = cv2.Canny(frame, 150, 250)  # Edge detection

#     flipped = cv2.flip(frame, 1)  # Flip the frame horizontally

#     cv2.imshow('Original', frame)
#     # cv2.imshow('Gray', gray)
#     # cv2.imshow('Blurred', blurred)  # Noise reduction
#     # cv2.imshow('Edges1', edges1)
#     # cv2.imshow('Edges2', edges2)

#     cv2.imshow('Flipped', flipped)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
