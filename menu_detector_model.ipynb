# %% [markdown]
# <a href="https://colab.research.google.com/github/shohruhinomjonov691-hub/computer_vision/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Menu Detector!")
# Out:
# Menu Detector!

# %%
# ---------------------------
# Import Libraries
# ---------------------------
from google.colab import drive
import torchvision.transforms as transforms
from PIL import Image, UnidentifiedImageError
from torch.utils.data import Dataset
import os
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define Dataset Path

DATASET_PATH = '/content/drive/MyDrive/food101_dataset'
print('Dataset_path:', DATASET_PATH)

CUSTOM_CLASS_MAPPING = {
    "hamburger": "hamburger",
    "hot_dog": "hot_dog",
    "chocolate_cake": "dessert", # label grouping | class consolidation
    "cheesecake": "dessert",     # label grouping | class consolidation
    "kebab": "kebab",
    "pilaf": "pilaf",
    "pizza": "pizza"
}


CLASSES = ['hamburger', 'hot_dog', 'dessert', 'kebab', 'pilaf', 'pizza']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)

print(NUM_CLASSES)
print(CLASS_TO_IDX)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                          std=[0.229, 0.224, 0.225])
])

# 300x400, 512x512
# 0 ~ 255
# 0.0 ~ 1.0 (float)
# H, W, C => C, H, W (tensor) | RGB = Red, Green, Blue
# Normalize
# pixel = (pixel - mean) /std
# Out:
# Dataset_path: /content/drive/MyDrive/food101_dataset
# 6
# {'hamburger': 0, 'hot_dog': 1, 'dessert': 2, 'kebab': 3, 'pilaf': 4, 'pizza': 5}

# %%
# ----------------------------------------
# Custom Dataset Class
# ----------------------------------------

class FoodDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        print('images_length', len(self.images))
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        print('image_path', img_path)
        label = self.labels[idx]
        print('label', label)
        try:
            image = Image.open(img_path).convert('RGB') # 3 Chennel
        except (UnidentifiedImageError, OSError):
            print(f"Skipping broken image: {img_path}")
            return self.__getitem__((idx + 1) % len(self.images))
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# ----------------------------------------
# Gather and Split Data
# ----------------------------------------
all_images = []
for original_class, mapped_class in CUSTOM_CLASS_MAPPING.items():
    class_path = os.path.join(DATASET_PATH, original_class) # /content/drive/MyDrive/food101_dataset/hamburger
    print('class_path:', class_path)
    if not os.path.exists(class_path):
        print(f"Warning: {class_path} not found")
        continue
    for img in os.listdir(class_path):
        if img.endswith(('.jpg', '.jpeg', '.png')): # .txt, .docx
            full_path = os.path.join(class_path, img) # /content/drive/MyDrive/food101_dataset/hamburger/100057.jpg
            all_images.append((full_path, CLASS_TO_IDX[mapped_class]))

np.random.shuffle(all_images)
split = int(0.8 * len(all_images))
train_data = all_images[:split] # 1000 | 800 trin_data | 200 val_data
val_data = all_images[split:]

train_images, train_labels = zip(*train_data)
val_images, val_labels = zip(*val_data)

print('all_images:', all_images)

dataset = FoodDataset(train_images, train_labels)
print(len(dataset))
img, lbl = dataset[0]
# Out:
# class_path: /content/drive/MyDrive/food101_dataset/hamburger
# class_path: /content/drive/MyDrive/food101_dataset/hot_dog
# class_path: /content/drive/MyDrive/food101_dataset/chocolate_cake
# class_path: /content/drive/MyDrive/food101_dataset/cheesecake
# class_path: /content/drive/MyDrive/food101_dataset/kebab
# class_path: /content/drive/MyDrive/food101_dataset/pilaf
# Warning: /content/drive/MyDrive/food101_dataset/pilaf not found
# class_path: /content/drive/MyDrive/food101_dataset/pizza
# all_images: [('/content/drive/MyDrive/food101_dataset/chocolate_cake/712477.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3112266.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/903277.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2374693.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1761259.jpg', 0), ('/content/drive/MyDrive/food101_dataset/pizza/3464858.jpg', 5), ('/content/drive/MyDrive/food101_dataset/pizza/3493457.jpg', 5), ('/content/drive/MyDrive/food101_dataset/pizza/5764.jpg', 5), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/283838.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/591179.jpg', 1), ('/content/drive/MyDrive/food101_dataset/hamburger/1890101.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/3671365.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/2797268.jpg', 0), ('/content/drive/MyDrive/food101_dataset/pizza/2664219.jpg', 5), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/222859.jpg', 2), ('/content/drive/MyDrive/food101_dataset/pizza/2999507.jpg', 5), ('/content/drive/MyDrive/food101_dataset/hot_dog/1233688.jpg', 1), ('/content/drive/MyDrive/food101_dataset/cheesecake/1642197.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3365013.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/690327.jpg', 1), ('/content/drive/MyDrive/food101_dataset/pizza/3042454.jpg', 5), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1747450.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1823305.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/1217686.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/591125.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1970489.jpg', 0), ('/content/drive/MyDrive/food101_dataset/pizza/2155475.jpg', 5), ('/content/drive/MyDrive/food101_dataset/cheesecake/3299474.jpg', 2), ('/content/drive/MyDrive/food101_dataset/pizza/1205154.jpg', 5), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1864488.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/94430.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3231160.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/3369593.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/665987.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/503973.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2702642.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/656458.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2148546.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1848845.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/845305.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/2319376.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hot_dog/2848330.jpg', 1), ('/content/drive/MyDrive/food101_dataset/hot_dog/3811761.jpg', 1), ('/content/drive/MyDrive/food101_dataset/pizza/3629996.jpg', 5), ('/content/drive/MyDrive/food101_dataset/hot_dog/87840.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1222977.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2828617.jpg', 2), ('/content/drive/MyDrive/food101_dataset/pizza/614981.jpg', 5), ('/content/drive/MyDrive/food101_dataset/hamburger/3807630.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/3807701.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/3033039.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/568417.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/3308293.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/1513140.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/3363702.jpg', 1), ('/content/drive/MyDrive/food101_dataset/hamburger/3577939.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hot_dog/1982180.jpg', 1), ('/content/drive/MyDrive/food101_dataset/pizza/2521769. ...
# images_length 4054
# 4054
# image_path /content/drive/MyDrive/food101_dataset/chocolate_cake/712477.jpg
# label 2
